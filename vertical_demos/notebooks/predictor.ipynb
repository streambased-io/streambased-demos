# %%
# Finance set
tableName='finance_markers'
filterColumn='investigationState'
filterValue='Complete'
classifierColumn='fraudtype'

# %%
# Load our recent data

# %load_ext sql
# %sql trino://streambased-server:8080/kafka
result = %sql SELECT * FROM kafka.streambased.{{tableName}} LIMIT 100
import pandas as pd
df = result.DataFrame()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Running query in 'trino://streambased-server:8080/kafka'

# %%
# Load the model

import time
import pandas as pd
import pandas as pd
from joblib import dump, load
from river import tree
from joblib import load

features = [column for column in df.columns if column not in [filterColumn, '_partition_id', '_partition_offset',
                                                               '_message_corrupt', '_message', '_headers',
                                                               '_message_length', '_key_corrupt', '_key',
                                                               '_key_length', '_timestamp', classifierColumn]]

# Load the pre-trained model
model_path = "hoeffding_tree_model.joblib"
model = load(model_path)

# %%
# Simulate incoming data stream (for demonstration, let's use a portion of your existing DataFrame)
# In a real scenario, this data could come from a live data source
streaming_data = df[features]  # Let's assume we're making predictions for the first 10 rows

# Iterate over each row in your streaming data to make predictions
for index, row in streaming_data.iterrows():
    # Convert the row to a dict of features
    x = row.to_dict()
    
    # Make a prediction for the current set of features
    y_pred = model.predict_one(x)
    
    # Optionally, you can print or log the prediction
    print(f"Predicted class for row {index}: {y_pred}")
# Out:
# Predicted class for row 0: Identity Theft
# Predicted class for row 1: Insurance Fraud
# Predicted class for row 2: Identity Theft
# Predicted class for row 3: Credit Card Fraud
# Predicted class for row 4: Credit Card Fraud
# Predicted class for row 5: Credit Card Fraud
# Predicted class for row 6: Credit Card Fraud
# Predicted class for row 7: Insurance Fraud
# Predicted class for row 8: Tax Evasion
# Predicted class for row 9: Payment Fraud
# Predicted class for row 10: Credit Card Fraud
# Predicted class for row 11: Insurance Fraud
# Predicted class for row 12: Credit Card Fraud
# Predicted class for row 13: Identity Theft
# Predicted class for row 14: Insurance Fraud
# Predicted class for row 15: Identity Theft
# Predicted class for row 16: Insurance Fraud
# Predicted class for row 17: Insurance Fraud
# Predicted class for row 18: Payment Fraud
# Predicted class for row 19: Insurance Fraud
# Predicted class for row 20: Credit Card Fraud
# Predicted class for row 21: Insurance Fraud
# Predicted class for row 22: Credit Card Fraud
# Predicted class for row 23: Payment Fraud
# Predicted class for row 24: Identity Theft
# Predicted class for row 25: Identity Theft
# Predicted class for row 26: Identity Theft
# Predicted class for row 27: Identity Theft
# Predicted class for row 28: Insurance Fraud
# Predicted class for row 29: Credit Card Fraud
# Predicted class for row 30: Payment Fraud
# Predicted class for row 31: Insurance Fraud
# Predicted class for row 32: Insurance Fraud
# Predicted class for row 33: Insurance Fraud
# Predicted class for row 34: Identity Theft
# Predicted class for row 35: Payment Fraud
# Predicted class for row 36: Insurance Fraud
# Predicted class for row 37: Credit Card Fraud
# Predicted class for row 38: Credit Card Fraud
# Predicted class for row 39: Tax Evasion
# Predicted class for row 40: Identity Theft
# Predicted class for row 41: Identity Theft
# Predicted class for row 42: Payment Fraud
# Predicted class for row 43: Payment Fraud
# Predicted class for row 44: Identity Theft
# Predicted class for row 45: Insurance Fraud
# Predicted class for row 46: Tax Evasion
# Predicted class for row 47: Insurance Fraud
# Predicted class for row 48: Credit Card Fraud
# Predicted class for row 49: Identity Theft
# Predicted class for row 50: Identity Theft
# Predicted class for row 51: Tax Evasion
# Predicted class for row 52: Payment Fraud
# Predicted class for row 53: Credit Card Fraud
# Predicted class for row 54: Credit Card Fraud
# Predicted class for row 55: Payment Fraud
# Predicted class for row 56: Credit Card Fraud
# Predicted class for row 57: Identity Theft
# Predicted class for row 58: Identity Theft
# Predicted class for row 59: Insurance Fraud
# Predicted class for row 60: Identity Theft
# Predicted class for row 61: Insurance Fraud
# Predicted class for row 62: Identity Theft
# Predicted class for row 63: Insurance Fraud
# Predicted class for row 64: Payment Fraud
# Predicted class for row 65: Credit Card Fraud
# Predicted class for row 66: Identity Theft
# Predicted class for row 67: Identity Theft
# Predicted class for row 68: Identity Theft
# Predicted class for row 69: Tax Evasion
# Predicted class for row 70: Identity Theft
# Predicted class for row 71: Credit Card Fraud
# Predicted class for row 72: Credit Card Fraud
# Predicted class for row 73: Credit Card Fraud
# Predicted class for row 74: Insurance Fraud
# Predicted class for row 75: Insurance Fraud
# Predicted class for row 76: Insurance Fraud
# Predicted class for row 77: Tax Evasion
# Predicted class for row 78: Identity Theft
# Predicted class for row 79: Insurance Fraud
# Predicted class for row 80: Insurance Fraud
# Predicted class for row 81: Payment Fraud
# Predicted class for row 82: Credit Card Fraud
# Predicted class for row 83: Credit Card Fraud
# Predicted class for row 84: Tax Evasion
# Predicted class for row 85: Credit Card Fraud
# Predicted class for row 86: Tax Evasion
# Predicted class for row 87: Payment Fraud
# Predicted class for row 88: Insurance Fraud
# Predicted class for row 89: Credit Card Fraud
# Predicted class for row 90: Credit Card Fraud
# Predicted class for row 91: Credit Card Fraud
# Predicted class for row 92: Identity Theft
# Predicted class for row 93: Insurance Fraud
# Predicted class for row 94: Identity Theft
# Predicted class for row 95: Tax Evasion
# Predicted class for row 96: Tax Evasion
# Predicted class for row 97: Credit Card Fraud
# Predicted class for row 98: Credit Card Fraud
# Predicted class for row 99: Credit Card Fraud

# %%
df.head()
# Out:
#            fraudtype  transcountabove1stddev  multipleinternationtransactions  \
# 0  Credit Card Fraud                       1                                0
# 1      Payment Fraud                       1                                1
# 2  Credit Card Fraud                       1                                0
# 3    Insurance Fraud                       0                                1
# 4  Credit Card Fraud                       0                                1
#
#    multipleaddresschanges  transamountabove1stddev  complaints  \
# 0                       0                        1           1
# 1                       1                        0           0
# 2                       0                        1           1
# 3                       0                        1           1
# 4                       1                        1           0
#
#    above10adjustments  multipledocumentverificationattempts  \
# 0                   1                                     1
# 1                   1                                     1
# 2                   1                                     1
# 3                   0                                     1
# 4                   0                                     1
#
#    accountmorethan6monthsold investigationstate  _partition_id  \
# 0                          1           Complete              0
# 1                          0           Complete              0
# 2                          0           Complete              0
# 3                          0           Complete              0
# 4                          0           Complete              0
#
#    _partition_offset  _message_corrupt  \
# 0                  0             False
# 1                  1             False
# 2                  2             False
# 3                  3             False
# 4                  4             False
#
#                                    _message _headers  _message_length  \
# 0  "Credit Card FraudComplete       {}               40
# 1      Payment FraudComplete       {}               36
# 2  "Credit Card FraudComplete       {}               40
# 3
# Insurance FraudComplete       {}               38
# 4  "Credit Card FraudComplete       {}               40
#
#    _key_corrupt  _key  _key_length              _timestamp
# 0         False  None            0 2024-03-04 11:02:33.242
# 1         False  None            0 2024-03-04 11:02:33.254
# 2         False  None            0 2024-03-04 11:02:33.254
# 3         False  None            0 2024-03-04 11:02:33.255
# 4         False  None            0 2024-03-04 11:02:33.255
