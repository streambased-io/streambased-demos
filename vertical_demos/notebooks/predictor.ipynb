# %%
# Finance set
tableName='finance_markers'
filterColumn='investigationState'
filterValue='Complete'
classifierColumn='fraudtype'

# %%
# Load our recent data

# %load_ext sql
# %sql trino://streambased-server:8080/kafka
result = %sql SELECT * FROM kafka.streambased.{{tableName}} LIMIT 100
import pandas as pd
df = result.DataFrame()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Running query in 'trino://streambased-server:8080/kafka'

# %%
# Load the model

import time
import pandas as pd
import pandas as pd
from joblib import dump, load
from river import tree
from joblib import load

features = [column for column in df.columns if column not in [filterColumn, '_partition_id', '_partition_offset',
                                                               '_message_corrupt', '_message', '_headers',
                                                               '_message_length', '_key_corrupt', '_key',
                                                               '_key_length', '_timestamp', classifierColumn]]

# Load the pre-trained model
model_path = "hoeffding_tree_model.joblib"
model = load(model_path)

# %%
# Simulate incoming data stream (for demonstration, let's use a portion of your existing DataFrame)
# In a real scenario, this data could come from a live data source
streaming_data = df[features]  # Let's assume we're making predictions for the first 10 rows

# Iterate over each row in your streaming data to make predictions
for index, row in streaming_data.iterrows():
    # Convert the row to a dict of features
    x = row.to_dict()
    
    # Make a prediction for the current set of features
    y_pred = model.predict_one(x)
    
    # Optionally, you can print or log the prediction
    print(f"Predicted class for row {index}: {y_pred}")
# Out:
# Predicted class for row 0: Payment Fraud
# Predicted class for row 1: Payment Fraud
# Predicted class for row 2: Payment Fraud
# Predicted class for row 3: Payment Fraud
# Predicted class for row 4: Payment Fraud
# Predicted class for row 5: Payment Fraud
# Predicted class for row 6: Payment Fraud
# Predicted class for row 7: Payment Fraud
# Predicted class for row 8: Payment Fraud
# Predicted class for row 9: Payment Fraud
# Predicted class for row 10: Payment Fraud
# Predicted class for row 11: Payment Fraud
# Predicted class for row 12: Payment Fraud
# Predicted class for row 13: Payment Fraud
# Predicted class for row 14: Payment Fraud
# Predicted class for row 15: Payment Fraud
# Predicted class for row 16: Payment Fraud
# Predicted class for row 17: Payment Fraud
# Predicted class for row 18: Payment Fraud
# Predicted class for row 19: Payment Fraud
# Predicted class for row 20: Payment Fraud
# Predicted class for row 21: Payment Fraud
# Predicted class for row 22: Payment Fraud
# Predicted class for row 23: Payment Fraud
# Predicted class for row 24: Payment Fraud
# Predicted class for row 25: Payment Fraud
# Predicted class for row 26: Payment Fraud
# Predicted class for row 27: Payment Fraud
# Predicted class for row 28: Payment Fraud
# Predicted class for row 29: Payment Fraud
# Predicted class for row 30: Payment Fraud
# Predicted class for row 31: Payment Fraud
# Predicted class for row 32: Payment Fraud
# Predicted class for row 33: Payment Fraud
# Predicted class for row 34: Payment Fraud
# Predicted class for row 35: Payment Fraud
# Predicted class for row 36: Payment Fraud
# Predicted class for row 37: Payment Fraud
# Predicted class for row 38: Payment Fraud
# Predicted class for row 39: Payment Fraud
# Predicted class for row 40: Payment Fraud
# Predicted class for row 41: Payment Fraud
# Predicted class for row 42: Payment Fraud
# Predicted class for row 43: Payment Fraud
# Predicted class for row 44: Payment Fraud
# Predicted class for row 45: Payment Fraud
# Predicted class for row 46: Payment Fraud
# Predicted class for row 47: Payment Fraud
# Predicted class for row 48: Payment Fraud
# Predicted class for row 49: Payment Fraud
# Predicted class for row 50: Payment Fraud
# Predicted class for row 51: Payment Fraud
# Predicted class for row 52: Payment Fraud
# Predicted class for row 53: Payment Fraud
# Predicted class for row 54: Payment Fraud
# Predicted class for row 55: Payment Fraud
# Predicted class for row 56: Payment Fraud
# Predicted class for row 57: Payment Fraud
# Predicted class for row 58: Payment Fraud
# Predicted class for row 59: Payment Fraud
# Predicted class for row 60: Payment Fraud
# Predicted class for row 61: Payment Fraud
# Predicted class for row 62: Payment Fraud
# Predicted class for row 63: Payment Fraud
# Predicted class for row 64: Payment Fraud
# Predicted class for row 65: Payment Fraud
# Predicted class for row 66: Payment Fraud
# Predicted class for row 67: Payment Fraud
# Predicted class for row 68: Payment Fraud
# Predicted class for row 69: Payment Fraud
# Predicted class for row 70: Payment Fraud
# Predicted class for row 71: Payment Fraud
# Predicted class for row 72: Payment Fraud
# Predicted class for row 73: Payment Fraud
# Predicted class for row 74: Payment Fraud
# Predicted class for row 75: Payment Fraud
# Predicted class for row 76: Payment Fraud
# Predicted class for row 77: Payment Fraud
# Predicted class for row 78: Payment Fraud
# Predicted class for row 79: Payment Fraud
# Predicted class for row 80: Payment Fraud
# Predicted class for row 81: Payment Fraud
# Predicted class for row 82: Payment Fraud
# Predicted class for row 83: Payment Fraud
# Predicted class for row 84: Payment Fraud
# Predicted class for row 85: Payment Fraud
# Predicted class for row 86: Payment Fraud
# Predicted class for row 87: Payment Fraud
# Predicted class for row 88: Payment Fraud
# Predicted class for row 89: Payment Fraud
# Predicted class for row 90: Payment Fraud
# Predicted class for row 91: Payment Fraud
# Predicted class for row 92: Payment Fraud
# Predicted class for row 93: Payment Fraud
# Predicted class for row 94: Payment Fraud
# Predicted class for row 95: Payment Fraud
# Predicted class for row 96: Payment Fraud
# Predicted class for row 97: Payment Fraud
# Predicted class for row 98: Payment Fraud
# Predicted class for row 99: Payment Fraud
